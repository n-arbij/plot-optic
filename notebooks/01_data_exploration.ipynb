# %% [markdown]
# # Project: Data Cleaning and Visualization

# %% [markdown]
# #### Objective
# This notebook explores the raw dataset to understand its structure and identify data quality issues. At this stage, no cleaning or transformation are performed. The goal is to observe, document and plan.

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("seaborne-v0_8")
# %matplotlib inline

# %% [markdown]
# #### Load Raw Data

# %%
df = pd.read_csv("../data/raw/dataset.csv")
df.head()

# %% [markdown]
# Observation:
# Each row represents a single record. The dataset appears to be transactional in nature.

# %% [markdown]
# #### Dataset Size

# %%
df.shape

# %% [markdown]
# Observation:
# The dataset contains several thousand records, making it suitable for exploratory analysis and visualization.

# %% [markdown]
# #### Column Overview

# %%
df.columns

# %% [markdown]
# Observation:
# Column names are understandable but some use inconsistent formatting, which may affect readability and analysis.

# %% [markdown]
# #### Data Types and Missing Values

# %%
df.info()

# %% [markdown]
# Key Observations:
# - Some numeric fields are stored as text
# - Data fields are not ywt in datetime format
# - Several columns contain missing values

# %% [markdown]
# #### Summary Statistics

# %%
df.describe(include='all')

# %% [markdown]
# Observation:
# Numeric columns show wide ranges, suggesting the possible presence of outliers

# %% [markdown]
# #### Missing Values Check

# %%
df.isnull().sum()

# %% [markdown]
# Observation:
# Certain columns have a high proportion of missing values and will require careful handling during cleaning

# %% [markdown]
# #### Duplicate Records

# %%
df.duplicated().sum()

# %% [markdown]
# Observation:
# Duplicate records exist and may distort analysis if not removed

# %% [markdown]
# #### Categorical Data Review

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].value_counts().head())

# %% [markdown]
# Observation:
# Some categorical columns show inconsistent capitalization and spelling.

# %% [markdown]
# #### Numerical Distribution

# %%
numerical_cols = df.select_dtypes(include=np.number).columns

for col in numerical_cols:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# Observation:
# Several numeric variables show skewed distribution and potential outliers.

# %% [markdown]
# #### Data Quality Issues Identified

# %% [markdown]
# - Missing values in multiple columns
# - Incorrect data types (dates and numeric field)
# - Duplicate records
# - Inconsistent categorical values
# - Potential outliers in numerical data

# %% [markdown]
# #### Cleaning Plan

# %% [markdown]
# The following actions will be taken in the next notebook:
# - Convert date columns to datetime format
# - Handle missing values using appropriate strategies
# - Remove duplicate records
# - Standardize categorical values
# - Investigate and manage outliers

# %% [markdown]
# #### Conclusion

# %% [markdown]
# This exploration provides a clear understanding of the dataset and highlisghts the key issues that nust be addressed before analysis. The next notebook focuses on systematic data cleaning.
